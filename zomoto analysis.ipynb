# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv',encoding="latin-1")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
df.sample()
# Out:
#       Restaurant ID                   Restaurant Name  Country Code  \
# 7938         310604  Platform Nine and Three Quarters             1
#
#            City                                            Address  \
# 7938  New Delhi  DDA Market, Satyam Enclave, Near Sukhdev Colle...
#
#          Locality        Locality Verbose  Longitude  Latitude  \
# 7938  Vivek Vihar  Vivek Vihar, New Delhi  77.303725  28.66736
#
#                              Cuisines  ...            Currency  \
# 7938  Cafe, North Indian, Continental  ...  Indian Rupees(Rs.)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 7938                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 7938                   No           2               2.6        Orange
#
#      Rating text Votes
# 7938     Average    54
#
# [1 rows x 21 columns]

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.isnull().sum().sum()
# Out:
# 9

# %%
df.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
False == 0
# Out:
# True

# %%
True == 1
# Out:
# True

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.corr()
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# Longitude                         0.045891    -0.078939         -0.116818
# ...

# %%
import seaborn as sns

# %%
# sns.scatterplot()

# %%
sns.scatterplot(x="Restaurant ID",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant ID', ylabel='Rating text'>

# %%
sns.scatterplot(x="Restaurant Name",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Restaurant Name', ylabel='Rating text'>
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 140 (\x8c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 138 (\x8a) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 159 (\x9f) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 135 (\x87) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 157 (\x9d) missing from current font.
# ...

# %%
sns.scatterplot(x="City",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Rating text'>

# %%
sns.scatterplot(x="Country Code",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='Rating text'>

# %%
sns.scatterplot(x="Address",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Address', ylabel='Rating text'>
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 140 (\x8c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ) missing from current font.s\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 136 (\x88) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(x="Locality",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Locality', ylabel='Rating text'>
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 136 (\x88) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(x="Locality Verbose",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Locality Verbose', ylabel='Rating text'>
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 136 (\x88) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(x="Latitude",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Latitude', ylabel='Rating text'>

# %%
sns.scatterplot(x="Longitude",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Rating text'>

# %%
sns.scatterplot(x="Cuisines",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Cuisines', ylabel='Rating text'>

# %%
sns.scatterplot(x="Average Cost for two",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Rating text'>

# %%
sns.scatterplot(x="Currency",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Currency', ylabel='Rating text'>
# C:\Users\mudraboyina srinivas\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 140 (\x8c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(x="Has Table booking",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='Rating text'>

# %%
sns.scatterplot(x="Has Online delivery",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='Rating text'>

# %%
sns.scatterplot(x="Switch to order menu",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Switch to order menu', ylabel='Rating text'>

# %%
sns.scatterplot(x="Price range",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Rating text'>

# %%
sns.scatterplot(x="Aggregate rating",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating text'>

# %%
sns.scatterplot(x="Rating color",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='Rating text'>

# %%
sns.scatterplot(x="Votes",y="Rating text",data=df)
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Rating text'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %%
df.corr()
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# Longitude                         0.045891    -0.078939         -0.116818
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
round(0.905609,2)
# Out:
# 0.91

# %%
round(131.000000)
# Out:
# 131

# %%
df.describe()[1:]
# Out:
#       Restaurant ID  Country Code   Longitude   Latitude  \
# mean   9.051128e+06     18.365616   64.126574  25.854381
# std    8.791521e+06     56.750546   41.467058  11.007935
# min    5.300000e+01      1.000000 -157.948486 -41.330428
# 25%    3.019625e+05      1.000000   77.081343  28.478713
# 50%    6.004089e+06      1.000000   77.191964  28.570469
# 75%    1.835229e+07      1.000000   77.282006  28.642758
# max    1.850065e+07    216.000000  174.832089  55.976980
#
#       Average Cost for two  Price range  Aggregate rating         Votes
# mean           1199.210763     1.804837          2.666370    156.909748
# std           16121.183073     0.905609          1.516378    430.169145
# min               0.000000     1.000000          0.000000      0.000000
# 25%             250.000000     1.000000          2.500000      5.000000
# 50%             400.000000     2.000000          3.200000     31.000000
# 75%             700.000000     2.000000          3.700000    131.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2,linewidth=2,annot=False,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("variable summary")
plt.show('heatmap.png')
plt.show()
# Out:
#   Input In [44]
#     plt.xticks(fontsize=18)
#     ^
# SyntaxError: invalid syntax

# %%
import warnings

# %%
collist = df.columns.values

# %%
collist = df.columns.values
ncol =30
nrows =14

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist
# Out:
# array(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City',
#        'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes'], dtype=object)

# %%
len(list(range(0,len(collist))))
# Out:
# 21

# %%
for i in range (0,len(collist)):
    print(collist[i])
    break
# Out:
# Restaurant ID

# %%
df[collist[i]]
# Out:
# 0       6317637
# 1       6304287
# 2       6300002
# 3       6318506
# 4       6314302
#          ...
# 9546    5915730
# 9547    5908749
# 9548    5915807
# 9549    5916112
# 9550    5927402
# Name: Restaurant ID, Length: 9551, dtype: int64

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=df[collist[i]],color='green',orient='v')
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [54], in <cell line: 2>()
#       2 for i in range(0,len(collist)):
#       3     plt.subplot(nrows,ncol,i+1)
# ----> 4     sns.boxplot(data=df[collist[i]],color='green',orient='v')
#       5     plt.tight_layout()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
0.0000
# Out:
# 0.0

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %%
df.isnull().sum().sum()
# Out:
# 9

# %%
#df.fillna()

# %%
df['Restaurant ID'].fillna(value=df['Restaurant ID'].mean())
# Out:
# 0       6317637
# 1       6304287
# 2       6300002
# 3       6318506
# 4       6314302
#          ...
# 9546    5915730
# 9547    5908749
# 9548    5915807
# 9549    5916112
# 9550    5927402
# Name: Restaurant ID, Length: 9551, dtype: int64

# %%
sns.distplot(df["Votes"])
# Out:
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
sns.distplot(df["Price range"])
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Density'>

# %%
sns.distplot(df["Average Cost for two"])
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Density'>

# %%
sns.distplot(df["Aggregate rating"])
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Density'>

# %%
df.corr()
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# Longitude                         0.045891    -0.078939         -0.116818
# ...

# %%
df.corr()['Votes'].sort_values()
# Out:
# Restaurant ID          -0.147023
# Longitude              -0.085101
# Latitude               -0.022962
# Average Cost for two    0.067783
# Country Code            0.154530
# Price range             0.309444
# Aggregate rating        0.313691
# Votes                   1.000000
# Name: Votes, dtype: float64

# %%
import matplotlib.pyplot as plt
# size of columns
plt.figure(figsize=(15,7))

sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(1080,864))
sns.heatmap(round(df.describe()[1:].transpose(),linewidth=2),annot=False,fmt="f")
plt.xtricks(fontsize=18)
plt.ytricks(fontsize=12)
plt.title("Variables summary")
plt.savefig('heatmap.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [74], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(1080,864))
# ----> 3 sns.heatmap(round(df.describe()[1:].transpose(),linewidth=2),annot=False,fmt="f")
#       4 plt.xtricks(fontsize=18)
#       5 plt.ytricks(fontsize=12)
#
# TypeError: 'linewidth' is an invalid keyword argument for round()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df[collist[0]]
# Out:
# 0       6317637
# 1       6304287
# 2       6300002
# 3       6318506
# 4       6314302
#          ...
# 9546    5915730
# 9547    5908749
# 9548    5915807
# 9549    5916112
# 9550    5927402
# Name: Restaurant ID, Length: 9551, dtype: int64

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='green',orient='v')
    plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [79], in <cell line: 2>()
#       2 for i in range (0, len(collist)):
#       3     plt.subplot(nrows,ncol,i+1)
# ----> 4     sns.boxplot(data = df[collist[i]],color='green',orient='v')
#       5     plt.tight_layout()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001,.001,.01, .1, 1, 10],'random_state':list(range(0,10))}

ls = Lasso()
clf = Grid
clf.fit(features_train,target_train)

print(clf.best_params_)
SearchCV(ls,parameters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [80], in <cell line: 6>()
#       3 parameters = {'alpha':[.0001,.001,.01, .1, 1, 10],'random_state':list(range(0,10))}
#       5 ls = Lasso()
# ----> 6 clf = Grid
#       7 clf.fit(features_train,target_train)
#       9 print(clf.best_params_)
#
# NameError: name 'Grid' is not defined

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
collist
# Out:
# array(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City',
#        'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes'], dtype=object)

# %%
rf = RandomForestRegressor(criterion="mae",max_features="auto")
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
pred_decision = rf.predict(features_test)

rfs = r2_score(target_test,pred_decision)
print('R2 Score:'rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
#   Input In [84]
#     print('R2 Score:'rfs*100)
#                      ^
# SyntaxError: invalid syntax
